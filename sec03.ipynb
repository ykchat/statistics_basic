# %%
from scipy import stats
import numpy as np
import pandas as pd

# %%
# %matplotlib inline
import seaborn as sns

sns.set()

# %% [markdown]
# #### 27. 確率関数とパラメータ

# %%
p = 0.3 #パラメータ

x = np.arange(0, 2)
y = stats.bernoulli.pmf(k=x, p=p)

df = pd.DataFrame({"x": x, "probability": y})
sns.barplot(x="x", y="probability", data=df)
# Out:
# <AxesSubplot:xlabel='x', ylabel='probability'>

# %% [markdown]
# #### 29. 二項分布

# %%
n = 4
p = 0.3

x = np.arange(0, n+1)
y = stats.binom.pmf(k=x, n=n, p=p)

df = pd.DataFrame({"x": x, "probability": y})
sns.barplot(x="x", y="probability", data=df)
# Out:
# <AxesSubplot:xlabel='x', ylabel='probability'>

# %% [markdown]
# #### 31. 正規分布

# %%
mu = 170 #平均
sigma = 5 #標準偏差

step = 0.4
x = np.arange(start=150, stop=190+step, step=step)
y = stats.norm.pdf(x=x, loc=mu, scale=sigma)

df = pd.DataFrame({"x": x, "probability": y})
sns.lineplot(x="x", y="probability", data=df)
# Out:
# <AxesSubplot:xlabel='x', ylabel='probability'>

# %% [markdown]
# #### 32. 標準正規分布

# %%
mu = 0 #平均
sigma = 1 #標準偏差

step = 0.08
x = np.arange(start=-4, stop=4+step, step=step)
y = stats.norm.pdf(x=x, loc=mu, scale=sigma)

df = pd.DataFrame({"x": x, "probability": y})
sns.lineplot(x="x", y="probability", data=df)
# Out:
# <AxesSubplot:xlabel='x', ylabel='probability'>
